# %%
import random 
import json 

with open("1999-05-31.json", "r", encoding="utf-8") as f:
    data = json.load(f) 

candidats = random.sample(data["voc_jour"], 100)

print(candidats)
# Out:
# ['Polloni', 'Bourrely', 'cornemuse', 'Bénévolat', 'Vaires', 'Pequeriaux', 'joies', 'superbement', 'passants', 'Guyot', 'Guibal', 'encouragées', 'sandres', 'confrontée', 'Pigato', 'capital-risque', 'MCR', 'parties', 'Zussy', 'FONCIERE', 'Plein-Air', 'graines', 'statut', 'Fatmagül', 'mouchoirs', 'Vert', 'concerné', 'saumon', 'Joseph-Carez', 'fendre', 'inattendues', 'interceptait', 'Neuves', 'manifestations', 'Girardet', 'masses', 'enclavées', 'approuvé', 'trait', 'Villette', 'démarches', 'vercelloise', 'Mathias', 'tu', 'incapacitants', 'bouillon', 'Boulard', 'Tisserant', 'officieusement', 'Lembo', 'Void', 'hantent', 'Delvallée', 'REVHOC', 'alignaient', 'attractivité', 'avides', 'Othe', 'Etreval', 'contente', 'Guitares', 'PATRIMOINE', 'collectionneurs', 'personnalités', 'décisions', 'plein-pied', 'brader', 'libérées', 'Courneuve', 'quelques', 'Intégrale', 'Sûre', 'désignation', 'chausser', 'flatteuse', 'Soloviev', 'automatiquement', 'participent', 'obtenant', 'rassemblé', 'appréciés', '
# ...
